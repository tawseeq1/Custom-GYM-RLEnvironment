# %%
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

import numpy as np
import random
import os

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %%
Discrete(3).sample()
# Out:
# 2

# %%
Box(0,1,shape=(3,)).sample()
# Out:
# array([0.46122116, 0.19521162, 0.21260057], dtype=float32)

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 1), ('speed', array([12.043642], dtype=float32))])

# %%
MultiBinary(6).sample()
# Out:
# array([1, 1, 0, 1, 0, 0], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample()
# Out:
# array([3, 1, 0])

# %% [markdown]
# ## Building our Environment

# %%
class ShowerEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)
        self.observation_space = Box(low= 0, high=100, shape=(1,))
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60

    def step(self, action):
        self.state += action -1
        self.shower_length -= 1

        if self.state >=37 and self.state <=39:
            reward =1
        else:
            reward = -1

        if self.shower_length <= 0:
            done = True
        else:
            done = False

        info = {}

        return self.state, reward, done, info

    def render(self):

        pass

    def reset(self):
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)

        self.shower_length = 60
        return self.state

# %%
env=ShowerEnv()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.observation_space.sample()
# Out:
# array([60.908154], dtype=float32)

# %%
env.reset()
# Out:
# array([39.])

# %%
# from stable_baselines3.common.env_checker import check_env
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# check_env(env, warn=True)

# %% [markdown]
# ##testing

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-38
# Episode:2 Score:-12
# Episode:3 Score:-60
# Episode:4 Score:-18
# Episode:5 Score:-58

# %%
env.close()

# %% [markdown]
# ##train

# %%
# log_path = os.path.join('Training', 'Logs')
# if you want to save the logs

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -32.7    |
# | time/              |          |
# |    fps             | 497      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -36.4       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010655312 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000273   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -33.5       |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012924461 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00176     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 54          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -34.9       |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007039246 |
# |    clip_fraction        | 0.0084      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.000165   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0002      |
# |    value_loss           | 66          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30          |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0054001138 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 3.35e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 68.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.9       |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010076955 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.69e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 77.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.9       |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012205821 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 4.16e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 71.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.7        |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 8            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0043418985 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -3.11e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000349    |
# |    value_loss           | 70.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -28.6        |
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 9            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0033206288 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000112    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 65           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -31.9        |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 10           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0057031596 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -6.25e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 71.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -30.3       |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 11          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012109278 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 1.9e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 72.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.6       |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 12          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012524317 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000461   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 73.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.1        |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 13           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0027718665 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0104      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 71           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.8       |
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 14          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005137223 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000182   |
# |    value_loss           | 71.4        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -22.4         |
# | time/                   |               |
# |    fps                  | 434           |
# |    iterations           | 15            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00045875594 |
# |    clip_fraction        | 0.0187        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0.00251       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 27.8          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 0.000369      |
# |    value_loss           | 72.3          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -19.5      |
# | time/                   |            |
# |    fps                  | 432        |
# |    iterations           | 16         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01294821 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.02       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.1       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 64.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 17          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009611338 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0565     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00976    |
# |    value_loss           | 64.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 18          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008557134 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00142    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.8       |
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 19          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009043298 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000446    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 66          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.48       |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 20          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012297919 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0472     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 49.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -7.2        |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 21          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010059927 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000176    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 50.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 22           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0050664404 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000522     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 47.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 6.18         |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 23           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0039421674 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00428      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.1         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00927     |
# |    value_loss           | 44.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 12.2       |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 24         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00798098 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.0154    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.4       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.000828  |
# |    value_loss           | 42.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 25          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009919507 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.000158   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 26          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010217715 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00317     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 29.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23.9        |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 27          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007896768 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -7.56e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.000835    |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26.7        |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 28          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012061741 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00165     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.8        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 29          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012295757 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00283     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 41.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 30          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.022983655 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00263    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00311     |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 31          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010749886 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.000249   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 49.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 37.5       |
# | time/                   |            |
# |    fps                  | 439        |
# |    iterations           | 32         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02238004 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.989     |
# |    explained_variance   | -0.000127  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.5       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.00774    |
# |    value_loss           | 55.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.7        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 33          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019625366 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 7.27e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 58.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 38.5       |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 34         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01630098 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.983     |
# |    explained_variance   | 7.69e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.2       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00224   |
# |    value_loss           | 55.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40          |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 35          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012418248 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 8.73e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00644     |
# |    value_loss           | 59.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.3        |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 36          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012062318 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | -4.59e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00598     |
# |    value_loss           | 63.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.8        |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 37          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014139539 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 1.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00778     |
# |    value_loss           | 65.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 45.7         |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 38           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0151742175 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 3.61e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.5         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00294      |
# |    value_loss           | 74.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.8       |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 39         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01562194 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.97      |
# |    explained_variance   | 7.63e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.1       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00628    |
# |    value_loss           | 77         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 40          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028941948 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | -4.53e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0218      |
# |    value_loss           | 77.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.4        |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 41          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021558274 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | -1.43e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 81.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.2        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 42          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.033339005 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 8.58e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.7        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 82.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.9        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 43          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009946605 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00954     |
# |    value_loss           | 84.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 439        |
# |    iterations           | 44         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03173934 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.957     |
# |    explained_variance   | -7.63e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.5       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00896    |
# |    value_loss           | 85.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49.8       |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 45         |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02414294 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.954     |
# |    explained_variance   | -2.98e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.7       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0125     |
# |    value_loss           | 89.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.5        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 46          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006983051 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | -2.38e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 90.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 47          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013415369 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | -7.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0099      |
# |    value_loss           | 84.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 48          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.026808247 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0161      |
# |    value_loss           | 92.3        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 47.2      |
# | time/                   |           |
# |    fps                  | 440       |
# |    iterations           | 49        |
# |    time_elapsed         | 227       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0635737 |
# |    clip_fraction        | 0.298     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.948    |
# |    explained_variance   | 1.91e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 33.7      |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 0.0192    |
# |    value_loss           | 88.3      |
# ---------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (59.2, 0.9797958971132712)
